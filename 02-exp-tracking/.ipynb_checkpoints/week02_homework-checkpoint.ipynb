# %%
import os 
import sys
import pandas as pd

# %% [markdown]
# ### Q1 Install MLflow

# %%
# !mlflow --version
# Out:
# mlflow, version 1.26.1

# %% [markdown]
# ### Q2 Download and preprocess the data

# %%
# !python preprocess_data.py --raw_data_path data/ --dest_path ./output

# %%
# Count number of files in ./output 
print("Number of files in output directory: {}".format(len([name for name in os.listdir('./output')])))
# Out:
# Number of files in output directory: 4

# %% [markdown]
# ### Q3 Train a model with autolog

# %%
# !python train.py
# Out:
# 2022/05/28 16:24:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/mlops_zoomcamp/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils."
# rmse: 6.729070933590364

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Number of autologged parameters: 17

# %% [markdown]
# ### Q4 Launch the tracking server locally

# %% [markdown]
# mlflow ui --backend-store-uri sqlite:///mlflow.db --default-artifact-root artifacts/

# %% [markdown]
# ### Q5 Tune the hyperparameters of the model

# %%
# !python hpo.py
# Out:
# 2022/05/28 16:36:04 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
# 100%|█████████| 50/50 [06:55<00:00,  8.30s/trial, best loss: 6.6284257482044735]

# %%
# Lowest validation RMSE: 6.628

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q6 Promote the best model to the model registry

# %%
# !python register_model.py
# Out:
# 2022/05/28 16:53:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/mlops_zoomcamp/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils."
# Best test rmse: 6.547886185595423
# Successfully registered model 'random-forest-best-model'.
# 2022/05/28 16:54:53 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: random-forest-best-model, version 1
# Created version '1' of model 'random-forest-best-model'.
