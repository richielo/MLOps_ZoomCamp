# %%
import os 
import sys
import pandas as pd

# %% [markdown]
# ### Q1 Converting the script to a Prefect flow

# %%
# !python homework.py
# Out:
# 12:06:13.298 | INFO    | prefect.engine - Created flow run 'vermilion-labrador' for flow 'main'
# 12:06:13.298 | INFO    | Flow run 'vermilion-labrador' - Using task runner 'ConcurrentTaskRunner'
# 12:06:13.309 | WARNING | Flow run 'vermilion-labrador' - No default storage is configured on the server. Results from this flow run will be stored in a temporary directory in its runtime environment.
# 12:06:13.364 | INFO    | Flow run 'vermilion-labrador' - Created task run 'read_data-4c7f9de4-0' for task 'read_data'
# 12:06:13.404 | INFO    | Flow run 'vermilion-labrador' - Created task run 'prepare_features-4ee39d9f-0' for task 'prepare_features'
# 12:06:14.730 | INFO    | Flow run 'vermilion-labrador' - Created task run 'read_data-4c7f9de4-1' for task 'read_data'
# 12:06:14.855 | INFO    | Flow run 'vermilion-labrador' - Created task run 'prepare_features-4ee39d9f-1' for task 'prepare_features'
# 12:06:14.980 | INFO    | Flow run 'vermilion-labrador' - Created task run 'train_model-7c866860-0' for task 'train_model'
# 12:06:22.594 | INFO    | Task run 'read_data-4c7f9de4-1' - Finished in state Completed()
# 12:06:25.531 | INFO    | Task run 'read_data-4c7f9de4-0' - Finished in state Completed()
# 12:06:26.404 | INFO    | Task run 'prepare_features-4ee39d9f-1' - The mean duration of validation is 16.859265811074096
# 12:06:28.051 | INFO    | Task run 'prepare_features-4ee39d9f-0' - The mean duration of training is 16.2472533682457
# 12:06:36.653 | INFO    | Task run 'prepare_features-4ee39d9f-1' - Finished in state Completed()
# 12:06:38.760 | INFO    | Task run 'prepare_features-4ee39d9f-0' - Finished in state Completed()
# 12:06:56.229 | INFO    | Task run 'train_model-7c866860-0' - The shape of X_train is (1109826, 525)
# 12:06:56.230 | INFO    | Task run 'train_model-7c866860-0' - The DictVectorizer has 525 features
# 12:07:46.940 | INFO    | Task run 'train_model-7c866860-0' - The MSE of training is: 10.528519414499133
# 12:07:48.408 | INFO    | Task run 'train_model-7c866860-0' - Finished in state Completed()
# 12:07:48.438 | INFO    | Flow run 'vermilion-labrador' - Created task run 'run_model-6559300c-0' for task 'run_model'
# 12:08:03.150 | INFO    | Task run 'run_model-6559300c-0' - The MSE of validation is: 11.014287796765931
# 12:08:04.405 | INFO    | Task run 'run_model-6559300c-0' - Finished in state Completed()
# 12:08:08.725 | INFO    | Flow run 'vermilion-labrador' - Finished in state Completed('All states completed.')

# %% [markdown]
# train_model needs to call .result()

# %% [markdown]
# ### Q2 Parameterizing the flow

# %%
# !python homework.py
# Out:
# 12:38:54.257 | INFO    | prefect.engine - Created flow run 'tangible-cuckoo' for flow 'main'
# 12:38:54.258 | INFO    | Flow run 'tangible-cuckoo' - Using task runner 'ConcurrentTaskRunner'
# 12:38:54.269 | WARNING | Flow run 'tangible-cuckoo' - No default storage is configured on the server. Results from this flow run will be stored in a temporary directory in its runtime environment.
# 12:38:54.326 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'get_paths-6e696e34-0' for task 'get_paths'
# 12:38:55.985 | INFO    | Task run 'get_paths-6e696e34-0' - Train path is: ./data/fhv_tripdata_2021-06.parquet
# 12:38:55.986 | INFO    | Task run 'get_paths-6e696e34-0' - Val path is: ./data/fhv_tripdata_2021-07.parquet
# 12:38:57.446 | INFO    | Task run 'get_paths-6e696e34-0' - Finished in state Completed()
# 12:38:57.476 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'read_data-4c7f9de4-0' for task 'read_data'
# 12:38:57.512 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'prepare_features-4ee39d9f-0' for task 'prepare_features'
# 12:38:58.881 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'read_data-4c7f9de4-1' for task 'read_data'
# 12:38:58.969 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'prepare_features-4ee39d9f-1' for task 'prepare_features'
# 12:38:59.056 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'train_model-7c866860-0' for task 'train_model'
# 12:39:08.212 | INFO    | Task run 'read_data-4c7f9de4-0' - Finished in state Completed()
# 12:39:10.094 | INFO    | Task run 'read_data-4c7f9de4-1' - Finished in state Completed()
# 12:39:11.450 | INFO    | Task run 'prepare_features-4ee39d9f-0' - The mean duration of training is 18.230538791569113
# 12:39:11.521 | INFO    | Task run 'prepare_features-4ee39d9f-1' - The mean duration of validation is 17.91113046137945
# 12:39:23.009 | INFO    | Task run 'prepare_features-4ee39d9f-0' - Finished in state Completed()
# 12:39:25.245 | INFO    | Task run 'prepare_features-4ee39d9f-1' - Finished in state Completed()
# 12:39:42.901 | INFO    | Task run 'train_model-7c866860-0' - The shape of X_train is (1222031, 525)
# 12:39:42.902 | INFO    | Task run 'train_model-7c866860-0' - The DictVectorizer has 525 features
# 12:40:22.161 | INFO    | Task run 'train_model-7c866860-0' - The MSE of training is: 11.789353672098182
# 12:40:23.659 | INFO    | Task run 'train_model-7c866860-0' - Finished in state Completed()
# 12:40:23.691 | INFO    | Flow run 'tangible-cuckoo' - Created task run 'run_model-6559300c-0' for task 'run_model'
# 12:40:41.399 | INFO    | Task run 'run_model-6559300c-0' - The MSE of validation is: 11.637031464483703
# 12:40:42.866 | INFO    | Task run 'run_model-6559300c-0' - Finished in state Completed()
# 12:40:47.823 | INFO    | Flow run 'tangible-cuckoo' - Finished in state Completed('All states completed.')

# %% [markdown]
# The MSE of validation is: 11.637031464483703

# %% [markdown]
# ### Q3 Saving the model and artifacts

# %%
# !python homework.py
# Out:
# 12:57:48.430 | INFO    | prefect.engine - Created flow run 'congenial-ibis' for flow 'main'
# 12:57:48.430 | INFO    | Flow run 'congenial-ibis' - Using task runner 'ConcurrentTaskRunner'
# 12:57:48.443 | WARNING | Flow run 'congenial-ibis' - No default storage is configured on the server. Results from this flow run will be stored in a temporary directory in its runtime environment.
# 12:57:48.585 | INFO    | Flow run 'congenial-ibis' - Created task run 'get_paths-6e696e34-0' for task 'get_paths'
# 12:57:50.297 | INFO    | Task run 'get_paths-6e696e34-0' - Train path is: ./data/fhv_tripdata_2021-06.parquet
# 12:57:50.311 | INFO    | Task run 'get_paths-6e696e34-0' - Val path is: ./data/fhv_tripdata_2021-07.parquet
# 12:57:51.953 | INFO    | Task run 'get_paths-6e696e34-0' - Finished in state Completed()
# 12:57:51.982 | INFO    | Flow run 'congenial-ibis' - Created task run 'read_data-4c7f9de4-0' for task 'read_data'
# 12:57:52.017 | INFO    | Flow run 'congenial-ibis' - Created task run 'prepare_features-4ee39d9f-0' for task 'prepare_features'
# 12:57:52.761 | INFO    | Flow run 'congenial-ibis' - Created task run 'read_data-4c7f9de4-1' for task 'read_data'
# 12:57:52.879 | INFO    | Flow run 'congenial-ibis' - Created task run 'prepare_features-4ee39d9f-1' for task 'prepare_features'
# 12:57:52.958 | INFO    | Flow run 'congenial-ibis' - Created task run 'train_model-7c866860-0' for task 'train_model'
# 12:58:01.431 | INFO    | Task run 'read_data-4c7f9de4-1' - Finished in state Completed()
# 12:58:03.608 | INFO    | Task run 'read_data-4c7f9de4-0' - Finished in state Completed()
# 12:58:03.872 | INFO    | Task run 'prepare_features-4ee39d9f-1' - The mean duration of validation is 17.91113046137945
# 12:58:05.720 | INFO    | Task run 'prepare_features-4ee39d9f-0' - The mean duration of training is 18.230538791569113
# 12:58:15.756 | INFO    | Task run 'prepare_features-4ee39d9f-0' - Finished in state Completed()
# 12:58:18.191 | INFO    | Task run 'prepare_features-4ee39d9f-1' - Finished in state Completed()
# 12:58:39.830 | INFO    | Task run 'train_model-7c866860-0' - The shape of X_train is (1222031, 525)
# 12:58:39.831 | INFO    | Task run 'train_model-7c866860-0' - The DictVectorizer has 525 features
# 12:59:17.299 | INFO    | Task run 'train_model-7c866860-0' - The MSE of training is: 11.789353672098182
# /home/mlops_zoomcamp/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 13:00:04.192 | INFO    | Task run 'train_model-7c866860-0' - Finished in state Completed()
# 13:00:04.218 | INFO    | Flow run 'congenial-ibis' - Created task run 'run_model-6559300c-0' for task 'run_model'
# 13:00:22.258 | INFO    | Task run 'run_model-6559300c-0' - The MSE of validation is: 11.637031464483703
# 13:00:23.596 | INFO    | Task run 'run_model-6559300c-0' - Finished in state Completed()
# 13:00:28.760 | INFO    | Flow run 'congenial-ibis' - Finished in state Completed('All states completed.')

# %%
size = os.path.getsize('models/preprocessor.b') 
print('Size of file is', size, 'bytes')
# Out:
# Size of file is 13191 bytes

# %% [markdown]
# ### Q4 Creating a deployment with a CronSchedule

# %% [markdown]
# cron="0 9 15 * *"

# %%
# !prefect deployment create homework.py
# Out:
# Loading deployment specifications from python script at 'homework.py'...
# /home/mlops_zoomcamp/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/prefect/deployments.py:247: UserWarning: You have configured local storage, this deployment will only be usable from the current machine..
#   warnings.warn(
# Creating deployment 'cron_schedule_model_training' for flow 'main'...
# Deploying flow script from
# '/home/mlops_zoomcamp/MLOps_ZoomCamp/03-orchestration/homework.py' using
# Temporary Local Storage...
# Created deployment 'main/cron_schedule_model_training'.
# View your new deployment with:
#
#     prefect deployment inspect 'main/cron_schedule_model_training'
# Created 1 deployments!

# %% [markdown]
# ### Q5 Viewing the Deployment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3 upcoming runs

# %% [markdown]
# ### Q6 Creating a work-queue

# %% [markdown]
# prefect work-queue ls
